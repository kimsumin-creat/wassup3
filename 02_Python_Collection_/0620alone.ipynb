# %% [markdown]
# # 0620 복습

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------
# aiobotocore                       2.7.0
# aiohttp                           3.9.3
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.12
# altair                            5.0.1
# anaconda-anon-usage               0.4.3
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.1.4
# anaconda-navigator                2.5.2
# anaconda-project                  0.11.1
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.0.5
# ...

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # paser

# %%
html = '''
<div id=prices >
    <table >
        <tr class=bb>
            <th class="bb lm lft">Date
            <th class="rgt bb">Open
            <th class="rgt bb">High
            <th class="rgt bb">Low
            <th class="rgt bb">Close
            <th class="rgt bb rm">Volume
        <tr>
            <td class="lm">Feb 28, 2014
            <td class="rgt">100.71
            <td class="rgt">100.71
            <td class="rgt">100.71
            <td class="rgt">100.71
            <td class="rgt rm">0
     </table>
'''

# %%
from bs4 import BeautifulSoup
import lxml

# %%
# lxml의 html파서
BeautifulSoup(html,'lxml')
# Out:
# <html><body><div id="prices">
# <table>
# <tr class="bb">
# <th class="bb lm lft">Date
#             </th><th class="rgt bb">Open
#             </th><th class="rgt bb">High
#             </th><th class="rgt bb">Low
#             </th><th class="rgt bb">Close
#             </th><th class="rgt bb rm">Volume
#         </th></tr><tr>
# <td class="lm">Feb 28, 2014
#             </td><td class="rgt">100.71
#             </td><td class="rgt">100.71
#             </td><td class="rgt">100.71
#             </td><td class="rgt">100.71
#             </td><td class="rgt rm">0
#      </td></tr></table>
# </div></body></html>

# %%
html_file = open('sample/market.html',encoding='utf-8')
html_src=html_file.read()
html_file.close()

# %%
print(html_src)
# Out:
# <html>
#     <body>
#         <h1> 과일 목록 </h1>
#         <div>
#                 <p id='banana' class='fruit' title='바나나'>
#                       <span class = 'price'> 3000원 </span>
#                       <span class = 'count'> 10개 </span>
#                       <span class = 'store'> 바나나가게 </span>
#                       <a href = 'https://www.banana.com'> banana.com </a>
#                 </p>
#                 <p id='cherry' class='fruit' title='체리'>
#                     <span class = 'price'> 100원 </span>
#                     <span class = 'count'> 50개 </span>
#                     <span class = 'store'> 체리가게</span>
#                     <a href = 'https://www.cherry.com'> cherry.com </a>
#                 </p>
#                 <p id='orange' class='fruit best' title='오렌지'>
#                     <span class = 'price'> 500원 </span>
#                     <span class = 'count'> 20개 </span>
#                     <span class = 'store'> 오렌지가게</span>
# ...

# %%
soup=BeautifulSoup(html_src,'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find('p')
# Out:
# <p class="fruit" id="banana" title="바나나">
# <span class="price"> 3000원 </span>
# <span class="count"> 10개 </span>
# <span class="store"> 바나나가게 </span>
# <a href="https://www.banana.com"> banana.com </a>
# </p>

# %%
hi=soup.find_all('p')

# %%
type(hi)
# Out:
# bs4.element.ResultSet

# %%
soup.find('p',id='banana')
# Out:
# <p class="fruit" id="banana" title="바나나">
# <span class="price"> 3000원 </span>
# <span class="count"> 10개 </span>
# <span class="store"> 바나나가게 </span>
# <a href="https://www.banana.com"> banana.com </a>
# </p>

# %%
soup.select('p span')
# Out:
# [<span class="price"> 3000원 </span>,
#  <span class="count"> 10개 </span>,
#  <span class="store"> 바나나가게 </span>,
#  <span class="price"> 100원 </span>,
#  <span class="count"> 50개 </span>,
#  <span class="store"> 체리가게</span>,
#  <span class="price"> 500원 </span>,
#  <span class="count"> 20개 </span>,
#  <span class="store"> 오렌지가게</span>,
#  <span>
#  <a href="https://www.orange.blog/">오렌지 효능</a>
#  </span>]

# %%
soup.select('span')
# Out:
# [<span class="price"> 3000원 </span>,
#  <span class="count"> 10개 </span>,
#  <span class="store"> 바나나가게 </span>,
#  <span class="price"> 100원 </span>,
#  <span class="count"> 50개 </span>,
#  <span class="store"> 체리가게</span>,
#  <span class="price"> 500원 </span>,
#  <span class="count"> 20개 </span>,
#  <span class="store"> 오렌지가게</span>,
#  <span>
#  <a href="https://www.orange.blog/">오렌지 효능</a>
#  </span>]

# %%
soup.select_one('p')
# Out:
# <p class="fruit" id="banana" title="바나나">
# <span class="price"> 3000원 </span>
# <span class="count"> 10개 </span>
# <span class="store"> 바나나가게 </span>
# <a href="https://www.banana.com"> banana.com </a>
# </p>

# %%
soup.select('.price')
# Out:
# [<span class="price"> 3000원 </span>,
#  <span class="price"> 100원 </span>,
#  <span class="price"> 500원 </span>]

# %%
soup.select('p#orange span')[:-1]
# Out:
# [<span class="price"> 500원 </span>,
#  <span class="count"> 20개 </span>,
#  <span class="store"> 오렌지가게</span>]

# %%
mylist=soup.select('.fruit.best a')
print(mylist)
type(mylist)
# Out:
# [<a href="https://www.orange.com"> orange.com </a>, <a href="https://www.orange.blog/">오렌지 효능</a>]
# bs4.element.ResultSet

# %%
mylist[1].text
# Out:
# '오렌지 효능'

# %%
for item in mylist:
    print(item['href'])
# Out:
# https://www.orange.com
# https://www.orange.blog/

# %%
for item in mylist:
    print(item['href'][0])
# Out:
# h
# h

# %%
item=soup.select('.fruit')

# %%
print(item)
# Out:
# [<p class="fruit" id="banana" title="바나나">
# <span class="price"> 3000원 </span>
# <span class="count"> 10개 </span>
# <span class="store"> 바나나가게 </span>
# <a href="https://www.banana.com"> banana.com </a>
# </p>, <p class="fruit" id="cherry" title="체리">
# <span class="price"> 100원 </span>
# <span class="count"> 50개 </span>
# <span class="store"> 체리가게</span>
# <a href="https://www.cherry.com"> cherry.com </a>
# </p>, <p class="fruit best" id="orange" title="오렌지">
# <span class="price"> 500원 </span>
# <span class="count"> 20개 </span>
# <span class="store"> 오렌지가게</span>
# <a href="https://www.orange.com"> orange.com </a>
# <span>
# <a href="https://www.orange.blog/">오렌지 효능</a>
# </span>
# </p>]

# %%
print(soup.find('span','price').text)
# Out:
#  3000원

# %% [markdown]
# for h in item:
#     name=h['title']
#     price=h.find('span','price').text
#     count=h.find('span','count').text
#     store=h.find('span','store').text
#     print(name,price,count,store)

# %%
e=soup.find('p',id='orange')

# %%
e.name
# Out:
# 'p'

# %%
e.parents
# Out:
# <generator object PageElement.parents at 0x00000273BC0B0640>

# %% [markdown]
# # requests

# %%
import requests
from bs4 import BeautifulSoup

# %%
PATH='https://finance.naver.com/'
resp=requests.get(PATH)

# %%
resp.text
# Out:
# '\n\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\t<title>네이버페이 증권</title>\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버페이 증권" />\n\n\n\n\n\n\t\n\t\t<meta property="og:title" content="네이버페이 증권"/>\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t<meta property="og:url" content="https://finance.naver.com"/>\n\t\t<meta property="og:description" content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공"/>\n    \n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버페이 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel
# ...

# %%
print(resp.text)
# Out:
#
#
#
# <html lang='ko'>
# <head>
#
#
#
#
#
#
# 				<title>네이버페이 증권</title>
#
#
#
#
#
#
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#
# <meta http-equiv="Content-Script-Type" content="text/javascript">
# <meta http-equiv="Content-Style-Type" content="text/css">
# <meta name="apple-mobile-web-app-title" content="네이버페이 증권" />
#
#
#
#
#
#
# 		<meta property="og:title" content="네이버페이 증권"/>
# 		<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>
# 		<meta property="og:url" content="https://finance.naver.com"/>
# 		<meta property="og:description" content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공"/>
#
#
#
# <meta property="og:type" content="article"/>
# <meta property="og:article:thumbnailUrl" content=""/>
# <meta property="og:article:author" content="네이버페이 증권"/>
# <meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>
#
#
#
#
#
#
# ...

# %%
src=resp.text

# %%
soup = BeautifulSoup(src, 'lxml') 
print(soup)
# Out:
# <html lang="ko">
# <head>
# <title>네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title"/>
# <meta content="네이버페이 증권" property="og:title"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/css/finance_header.css" rel="stylesheet" type="text/css"/>
# ...

# %%
src_list=soup.select('.section_strategy')
src_list
# Out:
# [<div class="section_strategy">
#  <h2 class="h_strategy"><span>주요뉴스</span></h2>
#  <ul>
#  <li>
#  <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322430" onclick="clickcr(this, 'tdn.list', '009_0005322430', '0', event);">“채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유</a></span>
#  </li>
#  <li>
#  <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=629&amp;article_id=0000297792" onclick="clickcr(this, 'tdn.list', '629_0000297792', '1', event);">신용등급 '줄강등' 우려에···증권사, 후순위채 발행 '러시'</a></span>
#  </li>
#  <li>
#  <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=001&amp;article_id=0014760730" onclick="clickcr(this, 'tdn.list', '001_0014760730', '2', event);">뉴욕증시, AI 열풍에 S&amp;P500 5천500선 첫 돌파하며 상승 출발</a></span>
#  </li>
#  <li>
# ...

# %%
src_list=soup.select('.section_strategy a')
src_list
# Out:
# [<a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322430" onclick="clickcr(this, 'tdn.list', '009_0005322430', '0', event);">“채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=629&amp;article_id=0000297792" onclick="clickcr(this, 'tdn.list', '629_0000297792', '1', event);">신용등급 '줄강등' 우려에···증권사, 후순위채 발행 '러시'</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=001&amp;article_id=0014760730" onclick="clickcr(this, 'tdn.list', '001_0014760730', '2', event);">뉴욕증시, AI 열풍에 S&amp;P500 5천500선 첫 돌파하며 상승 출발</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322427" onclick="clickcr(this, 'tdn.list', '009_0005322427', '3', event);">“이대로가면 시장 다 죽어”…금투세 폭탄에 ‘펀드런 공포’ 확산</a>,
# ...

# %%
print(len(src_list))
# Out:
# 7

# %%
src_list=soup.select('.section_strategy li a')
src_list
# Out:
# [<a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322430" onclick="clickcr(this, 'tdn.list', '009_0005322430', '0', event);">“채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=629&amp;article_id=0000297792" onclick="clickcr(this, 'tdn.list', '629_0000297792', '1', event);">신용등급 '줄강등' 우려에···증권사, 후순위채 발행 '러시'</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=001&amp;article_id=0014760730" onclick="clickcr(this, 'tdn.list', '001_0014760730', '2', event);">뉴욕증시, AI 열풍에 S&amp;P500 5천500선 첫 돌파하며 상승 출발</a>,
#  <a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322427" onclick="clickcr(this, 'tdn.list', '009_0005322427', '3', event);">“이대로가면 시장 다 죽어”…금투세 폭탄에 ‘펀드런 공포’ 확산</a>,
# ...

# %%
print(len(src_list))
# Out:
# 1

# %%
sample=src_list[0]
print(sample)
# Out:
# <a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322430" onclick="clickcr(this, 'tdn.list', '009_0005322430', '0', event);">“채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유</a>

# %%
sample.text
# Out:
# '“채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유'

# %%
sample['href']
# Out:
# '/news/news_read.naver?mode=mainnews&office_id=009&article_id=0005322430'

# %%
from urllib.parse import urljoin
urljoin(PATH,url)
# Out:
# 'https://finance.naver.com/“채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유'

# %%
news_url=[]
news_title=[]

for item in src_list:
    title=item.text
    url=urljoin(PATH,item['href'])
    news_title.append(title)
    news_url.append(url)
    print(title,url)
# Out:
# “채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유 https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=009&article_id=0005322430
# 신용등급 '줄강등' 우려에···증권사, 후순위채 발행 '러시' https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=629&article_id=0000297792
# 뉴욕증시, AI 열풍에 S&P500 5천500선 첫 돌파하며 상승 출발 https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=001&article_id=0014760730
# “이대로가면 시장 다 죽어”…금투세 폭탄에 ‘펀드런 공포’ 확산 https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=009&article_id=0005322427
# 엔비디아의 힘…S&P 5500 `첫 경험` https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=029&article_id=0002881927
# 엔비디아 또 나홀로 질주… 시총 1위 `넘사벽`? https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=029&article_id=0002881925

# %%
import pandas as pd

# %%
df=pd.DataFrame({'제목':news_title,'주소':news_url})
df
# Out:
#                                          제목  \
# 0  “채권으로 돈 좀 버나 했더니, 찬물 끼얹나”…개미들 ‘멘붕’ 빠진 이유
# 1        신용등급 '줄강등' 우려에···증권사, 후순위채 발행 '러시'
# 2   뉴욕증시, AI 열풍에 S&P500 5천500선 첫 돌파하며 상승 출발
# 3       “이대로가면 시장 다 죽어”…금투세 폭탄에 ‘펀드런 공포’ 확산
# 4                   엔비디아의 힘…S&P 5500 `첫 경험`
# 5               엔비디아 또 나홀로 질주… 시총 1위 `넘사벽`?
#
#                                                   주소
# 0  https://finance.naver.com/news/news_read.naver...
# 1  https://finance.naver.com/news/news_read.naver...
# 2  https://finance.naver.com/news/news_read.naver...
# 3  https://finance.naver.com/news/news_read.naver...
# 4  https://finance.naver.com/news/news_read.naver...
# 5  https://finance.naver.com/news/news_read.naver...

# %% [markdown]
# ## 0622 복습
# https://search.naver.com/search.naver?ssc=tab.news.all&where=news&sm=tab_jum&query=Newjeans

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
PATH='https://search.naver.com/search.naver'

# %%
keyword=input('검색하세요: ')
# Out:
# 검색하세요:  chat

# %%
resp4=requests.get(PATH,params={'query':keyword})
resp4
# Out:
# <Response [200]>

# %%
html_src=resp4.text
html_src
# Out:
# '<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="chat : 네이버 검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'chat\'의 네이버 검색 결과입니다."> <meta name="description" lang="ko" content="\'chat\'의 네이버 검색 결과입니다."> <title>chat : 네이버 검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240620.css"> <link rel="stylesheet" type="text/css" href=
# ...

# %%
soup=BeautifulSoup(html_src,'lxml')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
result=soup.select('.news_tit')
result
# Out:
# [<a class="news_tit" href="https://en.yna.co.kr/view/AEN20240621003900315?input=2106m" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=1&amp;i=880000D8_000000000000000014761182&amp;g=001.0014761182&amp;u='+urlencode(this.href));" target="_blank" title="NewJeans to make Japanese debut with 'Supernatural'"><mark>NewJeans</mark> to make Japanese debut with 'Supernatural'</a>,
#  <a class="news_tit" href="https://view.asiae.co.kr/article/2024062013175440512" onclick="return goOtherCR(this, 'a=nws_all*e.tit&amp;r=3&amp;i=88000385_000000000000000005434650&amp;g=277.0005434650&amp;u='+urlencode(this.href));" target="_blank" title="뉴진스, 슈퍼내추럴 발매 기념 '韓·日 팝업스토어' 개최">뉴진스, 슈퍼내추럴 발매 기념 '韓·日 팝업스토어' 개최</a>,
# ...

# %%
print(len(result))
print(result)
# Out:
# 4
# ...

# %%
for temp in result:
    print(temp.text,temp['href'])
# Out:
# NewJeans to make Japanese debut with 'Supernatural' https://en.yna.co.kr/view/AEN20240621003900315?input=2106m
# 뉴진스, 슈퍼내추럴 발매 기념 '韓·日 팝업스토어' 개최 https://view.asiae.co.kr/article/2024062013175440512
# 신세계 센텀시티, IPX와 함께 뉴진스 'How Sweet' 콘셉트 'PLAY LINE FRIENDS... http://www.fntoday.co.kr/news/articleView.html?idxno=323828
# Ador, Krafton vow to address sexual harassment involving NewJeans https://www.koreaherald.com/view.php?ud=20240621050566

# %% [markdown]
# ## melon 음악 가져오기
# https://www.melon.com/new/index.htm

# %%
import requests
from bs4 import BeautifulSoup

# %%
PATH='https://www.melon.com/chart/index.htm'

# %%
user={'user-Agent':'Mozilla/5.0 (Linux; Android 13; SM-G981B) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Mobile Safari/537.36'}
user
# Out:
# {'user-Agent': 'Mozilla/5.0 (Linux; Android 13; SM-G981B) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Mobile Safari/537.36'}

# %%
resp5=requests.get(PATH,headers=user)
resp5
# Out:
# <Response [200]>

# %%
html_src=resp5.text
html_src
# Out:
# '\n\r\n\t\r\n\t\t<meta http-equiv="REFRESH" content="0;url=https://m2.melon.com/index.htm#2?">\r\n\t\r\n\r\n'

# %%
soup=BeautifulSoup(html_src,'lxml')
soup
# Out:
# <html><head><meta content="0;url=https://m2.melon.com/index.htm#2?" http-equiv="REFRESH"/>
# </head></html>
